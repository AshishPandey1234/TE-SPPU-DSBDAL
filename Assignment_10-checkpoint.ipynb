# %%
import seaborn as sb
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = sb.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
print(df.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
df.hist(figsize=(12,12))
plt.show()

# %%
df['sepal_length'].isnull().sum()
# Out:
# 0

# %%
sb.histplot(data=df,x="sepal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sb.histplot(data=df,x="sepal_width")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sb.histplot(data=df,x="petal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sb.histplot(data=df,x="petal_width")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot(kind='box', subplots=True, layout=(3,2), figsize=(8,12));
plt.show()

# %%
print(boxplot.__toc__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(boxplot.__toc__)
#
# NameError: name 'boxplot' is not defined
