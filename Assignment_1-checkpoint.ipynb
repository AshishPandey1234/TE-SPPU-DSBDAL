# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("covid_19_clean_complete_2022.csv")
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
df.isna().any()
# Out:
# Province/State     True
# Country/Region    False
# Lat                True
# Long               True
# Date              False
# Confirmed         False
# Deaths            False
# Recovered         False
# Active            False
# WHO Region         True
# dtype: bool

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
df.shape
# Out:
# (214894, 10)

# %%
df.size
# Out:
# 2148940

# %%
df.describe()
# Out:
#                  Lat           Long     Confirmed         Deaths  \
# count  213348.000000  213348.000000  2.148940e+05  214894.000000
# mean       20.528131      22.735337  4.578132e+05    9310.764693
# std        25.899139      76.304185  2.708770e+06   47497.835275
# min       -71.949900    -178.116500  0.000000e+00       0.000000
# 25%         6.426991     -27.932425  2.530000e+02       2.000000
# 50%        22.233350      21.752000  5.223000e+03      71.000000
# 75%        41.166070      88.658375  9.892275e+04    1675.000000
# max        71.706900     178.065000  7.925051e+07  958144.000000
#
#           Recovered        Active
# count  2.148940e+05  2.148940e+05
# mean   1.079987e+05  3.405037e+05
# std    8.470111e+05  2.516382e+06
# min    0.000000e+00 -1.638280e+05
# 25%    0.000000e+00  1.600000e+01
# 50%    4.500000e+01  1.243000e+03
# 75%    5.115750e+03  2.644675e+04
# max    3.097475e+07  7.829236e+07

# %%
df.isnull().sum()
# Out:
# Province/State    149189
# Country/Region         0
# Lat                 1546
# Long                1546
# Date                   0
# Confirmed              0
# Deaths                 0
# Recovered              0
# Active                 0
# WHO Region          2319
# dtype: int64

# %%
df.isna().any()
# Out:
# Province/State     True
# Country/Region    False
# Lat                True
# Long               True
# Date              False
# Confirmed         False
# Deaths            False
# Recovered         False
# Active            False
# WHO Region         True
# dtype: bool

# %%
x=df['Confirmed'].mean()
print("mean of confirmed cases",x)
df['Confirmed'].fillna(x,inplace=True)
# Out:
# mean of confirmed cases 457813.1720848418

# %%
df.isnull().sum()
# Out:
# Province/State    149189
# Country/Region         0
# Lat                 1546
# Long                1546
# Date                   0
# Confirmed              0
# Deaths                 0
# Recovered              0
# Active                 0
# WHO Region          2319
# dtype: int64

# %%
x=df['Deaths'].mean()
print("mean of Deaths",x)
df['Deaths'].fillna(x,inplace=True)
# Out:
# mean of Deaths 9310.764693290646

# %%
x=df['Active'].mean()
print("mean of Active cases",x)
df['Active'].fillna(x,inplace=True)
# Out:
# mean of Active cases 340503.7048358726

# %%
x=df['Recovered'].mean()
print("mean of Recovered cases",x)
df['Recovered'].fillna(x,inplace=True)
# Out:
# mean of Recovered cases 107998.70255567861

# %%
df.isnull().sum()
# Out:
# Province/State    149189
# Country/Region         0
# Lat                 1546
# Long                1546
# Date                   0
# Confirmed              0
# Deaths                 0
# Recovered              0
# Active                 0
# WHO Region          2319
# dtype: int64

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Country/Region']=df['Country/Region'].astype('string')
df.dropna(subset=['Date'],inplace=True)

# %%
df.dtypes
# Out:
# Province/State            object
# Country/Region    string[python]
# Lat                      float64
# Long                     float64
# Date              datetime64[ns]
# Confirmed                  int64
# Deaths                     int64
# Recovered                  int64
# Active                     int64
# WHO Region                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Province/State    149189
# Country/Region         0
# Lat                 1546
# Long                1546
# Date                   0
# Confirmed              0
# Deaths                 0
# Recovered              0
# Active                 0
# WHO Region          2319
# dtype: int64

# %%
df
# Out:
#        Province/State        Country/Region        Lat        Long       Date  \
# 0                 NaN           Afghanistan  33.939110   67.709953 2020-01-22
# 1                 NaN               Albania  41.153300   20.168300 2020-01-22
# 2                 NaN               Algeria  28.033900    1.659600 2020-01-22
# 3                 NaN               Andorra  42.506300    1.521800 2020-01-22
# 4                 NaN                Angola -11.202700   17.873900 2020-01-22
# ...               ...                   ...        ...         ...        ...
# 214889            NaN    West Bank and Gaza  31.952200   35.233200 2022-03-04
# 214890            NaN  Winter Olympics 2022  39.904200  116.407400 2022-03-04
# 214891            NaN                 Yemen  15.552727   48.516388 2022-03-04
# 214892            NaN                Zambia -13.133897   27.849332 2022-03-04
# 214893            NaN              Zimbabwe -19.015438   29.154857 2022-03-04
#
# ...

# %%
x=pd.get_dummies(df['WHO Region'])
df.drop('Province/State', axis=1, inplace=True)
df=pd.concat([df,x],axis=1)
df
# Out:
#               Country/Region        Lat        Long       Date  Confirmed  \
# 0                Afghanistan  33.939110   67.709953 2020-01-22          0
# 1                    Albania  41.153300   20.168300 2020-01-22          0
# 2                    Algeria  28.033900    1.659600 2020-01-22          0
# 3                    Andorra  42.506300    1.521800 2020-01-22          0
# 4                     Angola -11.202700   17.873900 2020-01-22          0
# ...                      ...        ...         ...        ...        ...
# 214889    West Bank and Gaza  31.952200   35.233200 2022-03-04     649971
# 214890  Winter Olympics 2022  39.904200  116.407400 2022-03-04        530
# 214891                 Yemen  15.552727   48.516388 2022-03-04      11774
# 214892                Zambia -13.133897   27.849332 2022-03-04     313613
# 214893              Zimbabwe -19.015438   29.154857 2022-03-04     238739
#
#         Deaths  Recovered  Active             WHO Region  Africa  Americas  \
# ...

# %%
df.isnull().sum()
# Out:
# Country/Region              0
# Lat                      1546
# Long                     1546
# Date                        0
# Confirmed                   0
# Deaths                      0
# Recovered                   0
# Active                      0
# WHO Region               2319
# Africa                      0
# Americas                    0
# Eastern Mediterranean       0
# Europe                      0
# South-East Asia             0
# Western Pacific             0
# dtype: int64

# %%
df = df.drop(['WHO Region','Country/Region'], axis=1)
df.head()
# Out:
#         Lat       Long       Date  Confirmed  Deaths  Recovered  Active  \
# 0  33.93911  67.709953 2020-01-22          0       0          0       0
# 1  41.15330  20.168300 2020-01-22          0       0          0       0
# 2  28.03390   1.659600 2020-01-22          0       0          0       0
# 3  42.50630   1.521800 2020-01-22          0       0          0       0
# 4 -11.20270  17.873900 2020-01-22          0       0          0       0
#
#    Africa  Americas  Eastern Mediterranean  Europe  South-East Asia  \
# 0   False     False                   True   False            False
# 1   False     False                  False    True            False
# 2    True     False                  False   False            False
# 3   False     False                  False    True            False
# 4    True     False                  False   False            False
#
#    Western Pacific
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %%
df.isnull().sum()
# Out:
# Lat                      1546
# Long                     1546
# Date                        0
# Confirmed                   0
# Deaths                      0
# Recovered                   0
# Active                      0
# Africa                      0
# Americas                    0
# Eastern Mediterranean       0
# Europe                      0
# South-East Asia             0
# Western Pacific             0
# dtype: int64
